# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
# %matplotlib inline

# %%
pokemons = pd.read_csv('course-files/pokemon.csv')

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.ylabel('some numbers')
plt.show()

# %%
t=np.arange(0,5,0.2)
plt.plot(t,t,'b.', t,t**2,'g-.', t,t**3,'r--')
# Out:
# [<matplotlib.lines.Line2D at 0xda56c88>,
#  <matplotlib.lines.Line2D at 0xda56be0>,
#  <matplotlib.lines.Line2D at 0xda56ca0>]

# %%
Min = 0
Max = 4 * np.pi
Step = 0.1

x = np. arange(Min, Max, Step)
y = np.sin(x)

plt.plot(x,y,'k--')
plt.xlabel('angle')
plt.ylabel('sin(angle)')
plt.show()
